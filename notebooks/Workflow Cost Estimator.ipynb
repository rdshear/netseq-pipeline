# %% [markdown]
# # Workflow Cost Estimator
# This notebook demonstrates cost estimation for finished or in-progress workflows.
#
# This is an experimental feature:
#   - Cost estimates may not be accurate.
#   - CPUs, Memory, and runtime is pulled from Terra's Firecloud API
#     [monitorSubmission](https://api.firecloud.org/#/Submissions/monitorSubmission) endpoint. This information is
#     available for 42 days after workflow completion.
#   - GCP Instance type is assumed custom configurations of eith N1 or N2 instance type.
#
# *author: Brian Hannafious, Genomics Institute, University of California Santa Cruz*

# %% [markdown]
# Install the newest version of [terra-notebook-utils](https://github.com/DataBiosphere/terra-notebook-utils)

# %%
# %pip install --upgrade --no-cache-dir git+https://github.com/DataBiosphere/terra-notebook-utils
# Out:
# Collecting git+https://github.com/DataBiosphere/terra-notebook-utils
#   Cloning https://github.com/DataBiosphere/terra-notebook-utils to /tmp/pip-req-build-z026z9kf
#   Running command git clone -q https://github.com/DataBiosphere/terra-notebook-utils /tmp/pip-req-build-z026z9kf
#   Resolved https://github.com/DataBiosphere/terra-notebook-utils to commit a7985f11c220638b5c61ce3bd351b315df8fc084
# Collecting google-cloud-storage<1.39.0,>=1.38.0
#   Downloading google_cloud_storage-1.38.0-py2.py3-none-any.whl (103 kB)
#      |████████████████████████████████| 103 kB 5.4 MB/s eta 0:00:01:01
# Collecting gs-chunked-io<0.6,>=0.5.1
#   Downloading gs-chunked-io-0.5.2.tar.gz (8.1 kB)
# Collecting firecloud
#   Downloading firecloud-0.16.31.tar.gz (53 kB)
#      |████████████████████████████████| 53 kB 29.1 MB/s eta 0:00:01
# Collecting bgzip<0.4,>=0.3.5
#   Downloading bgzip-0.3.5.tar.gz (61 kB)
#      |████████████████████████████████| 61 kB 12.4 MB/s eta 0:00:01
# Collecting cli-builder<0.2,>=0.1.5
#   Downloading cli-builder-0.1.5.tar.gz (3.5 kB)
# Collecting oauth2client
#   Downloading oauth2client-4.1.3-py2.py3-none-any.whl (98 kB)
#      |████████████████████████████████| 98 kB 35.9 MB/s eta 0:00:01
# Collecting jmespath==0.10.0
#   Downloading jmespath-0.10.0-py2.py3-none-any.whl (24 kB)
# Collecting getm<0.1.0,>=0.0.4
#   Downloading getm-0.0.4.tar.gz (24 kB)
# Collecting jsonschema
#   Downloading jsonschema-4.0.1-py3-none-any.whl (69 kB)
#      |████████████████████████████████| 69 kB 35.7 MB/s eta 0:00:01
# Collecting requests
#   Downloading requests-2.26.0-py2.py3-none-any.whl (62 kB)
#      |████████████████████████████████| 62 kB 19.1 MB/s eta 0:00:01
# Collecting google-crc32c
#   Downloading google_crc32c-1.3.0-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (38 kB)
# Collecting google-resumable-media<2.0dev,>=1.2.0
#   Downloading google_resumable_media-1.3.3-py2.py3-none-any.whl (75 kB)
#      |████████████████████████████████| 75 kB 32.7 MB/s eta 0:00:01
# Collecting google-cloud-core<2.0dev,>=1.4.1
#   Downloading google_cloud_core-1.7.2-py2.py3-none-any.whl (28 kB)
# Collecting google-auth<2.0dev,>=1.11.0
#   Downloading google_auth-1.35.0-py2.py3-none-any.whl (152 kB)
#      |████████████████████████████████| 152 kB 17.3 MB/s eta 0:00:01
# Collecting setuptools>=40.3.0
#   Downloading setuptools-58.2.0-py3-none-any.whl (946 kB)
#      |████████████████████████████████| 946 kB 33.8 MB/s eta 0:00:01     |████████████▏                   | 358 kB 33.8 MB/s eta 0:00:01
# Collecting rsa<5,>=3.1.4
#   Downloading rsa-4.7.2-py3-none-any.whl (34 kB)
# Collecting cachetools<5.0,>=2.0.0
#   Downloading cachetools-4.2.4-py3-none-any.whl (10 kB)
# Collecting pyasn1-modules>=0.2.1
#   Downloading pyasn1_modules-0.2.8-py2.py3-none-any.whl (155 kB)
#      |████████████████████████████████| 155 kB 41.1 MB/s eta 0:00:01
# Collecting six>=1.9.0
#   Downloading six-1.16.0-py2.py3-none-any.whl (11 kB)
# Collecting google-api-core<2.0.0dev,>=1.21.0
#   Downloading google_api_core-1.31.3-py2.py3-none-any.whl (93 kB)
#      |████████████████████████████████| 93 kB 28.1 MB/s eta 0:00:01
# Collecting packaging>=14.3
#   Downloading packaging-21.0-py3-none-any.whl (40 kB)
#      |████████████████████████████████| 40 kB 32.8 MB/s eta 0:00:01
# Collecting pytz
#   Downloading pytz-2021.3-py2.py3-none-any.whl (503 kB)
#      |████████████████████████████████| 503 kB 42.8 MB/s eta 0:00:01
# Collecting googleapis-common-protos<2.0dev,>=1.6.0
#   Downloading googleapis_common_protos-1.53.0-py2.py3-none-any.whl (198 kB)
#      |████████████████████████████████| 198 kB 44.7 MB/s eta 0:00:01
# Collecting protobuf<3.18.0,>=3.12.0
#   Downloading protobuf-3.17.3-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (1.0 MB)
#      |████████████████████████████████| 1.0 MB 42.7 MB/s eta 0:00:01
# Collecting pyparsing>=2.0.2
#   Downloading pyparsing-2.4.7-py2.py3-none-any.whl (67 kB)
#      |████████████████████████████████| 67 kB 35.1 MB/s eta 0:00:01
# Collecting pyasn1<0.5.0,>=0.4.6
#   Downloading pyasn1-0.4.8-py2.py3-none-any.whl (77 kB)
#      |████████████████████████████████| 77 kB 39.2 MB/s eta 0:00:01
# Collecting charset-normalizer~=2.0.0
#   Downloading charset_normalizer-2.0.6-py3-none-any.whl (37 kB)
# Collecting idna<4,>=2.5
#   Downloading idna-3.2-py3-none-any.whl (59 kB)
#      |████████████████████████████████| 59 kB 32.4 MB/s eta 0:00:01
# Collecting certifi>=2017.4.17
#   Downloading certifi-2021.5.30-py2.py3-none-any.whl (145 kB)
#      |████████████████████████████████| 145 kB 45.0 MB/s eta 0:00:01
# Collecting urllib3<1.27,>=1.21.1
#   Downloading urllib3-1.26.7-py2.py3-none-any.whl (138 kB)
#      |████████████████████████████████| 138 kB 45.2 MB/s eta 0:00:01
# Collecting pydot
#   Downloading pydot-1.4.2-py2.py3-none-any.whl (21 kB)
# Collecting nose
#   Downloading nose-1.3.7-py3-none-any.whl (154 kB)
#      |████████████████████████████████| 154 kB 46.3 MB/s eta 0:00:01
# Collecting pylint==1.7.2
#   Downloading pylint-1.7.2-py2.py3-none-any.whl (644 kB)
#      |████████████████████████████████| 644 kB 43.7 MB/s eta 0:00:01
# Collecting mccabe
#   Downloading mccabe-0.6.1-py2.py3-none-any.whl (8.6 kB)
# Collecting astroid>=1.5.1
#   Downloading astroid-2.8.0-py3-none-any.whl (242 kB)
#      |████████████████████████████████| 242 kB 44.9 MB/s eta 0:00:01
# Collecting isort>=4.2.5
#   Downloading isort-5.9.3-py3-none-any.whl (106 kB)
#      |████████████████████████████████| 106 kB 47.3 MB/s eta 0:00:01
# Collecting wrapt<1.13,>=1.11
#   Downloading wrapt-1.12.1.tar.gz (27 kB)
# Collecting typing-extensions>=3.10
#   Downloading typing_extensions-3.10.0.2-py3-none-any.whl (26 kB)
# Collecting lazy-object-proxy>=1.4.0
#   Downloading lazy_object_proxy-1.6.0-cp37-cp37m-manylinux1_x86_64.whl (55 kB)
#      |████████████████████████████████| 55 kB 29.7 MB/s eta 0:00:01
# Collecting typed-ast<1.5,>=1.4.0
#   Downloading typed_ast-1.4.3-cp37-cp37m-manylinux1_x86_64.whl (743 kB)
#      |████████████████████████████████| 743 kB 36.2 MB/s eta 0:00:01
# Collecting attrs>=17.4.0
#   Downloading attrs-21.2.0-py2.py3-none-any.whl (53 kB)
#      |████████████████████████████████| 53 kB 29.4 MB/s eta 0:00:01
# Collecting importlib-metadata
#   Downloading importlib_metadata-4.8.1-py3-none-any.whl (17 kB)
# Collecting pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0
#   Downloading pyrsistent-0.18.0-cp37-cp37m-manylinux1_x86_64.whl (119 kB)
#      |████████████████████████████████| 119 kB 45.8 MB/s eta 0:00:01
# Collecting zipp>=0.5
#   Downloading zipp-3.6.0-py3-none-any.whl (5.3 kB)
# Collecting httplib2>=0.9.1
#   Downloading httplib2-0.19.1-py3-none-any.whl (95 kB)
#      |████████████████████████████████| 95 kB 37.9 MB/s eta 0:00:01
# Building wheels for collected packages: terra-notebook-utils, bgzip, cli-builder, getm, gs-chunked-io, firecloud, wrapt
#   Building wheel for terra-notebook-utils (setup.py) ... done
#   Created wheel for terra-notebook-utils: filename=terra_notebook_utils-0.8.1-py3-none-any.whl size=47105 sha256=673b9065173c43ad5ca3409d25f812e40bfb110572a1d3ba20d15cd9f194b6c4
#   Stored in directory: /tmp/pip-ephem-wheel-cache-3ouycfp4/wheels/b7/d9/9f/c25a763a4da619ca50a8ee11c6fb38a7a644bc117084dd3a43
#   Building wheel for bgzip (setup.py) ... done
#   Created wheel for bgzip: filename=bgzip-0.3.5-cp37-cp37m-linux_x86_64.whl size=137897 sha256=4a32e683a78b2a06a7ef885fc499669114c4f9027f8e4001ddca0c82dee6cc8f
#   Stored in directory: /tmp/pip-ephem-wheel-cache-3ouycfp4/wheels/63/45/84/5431b7bd7c1bb0e34edb3d6bf2475ff027f95fc115107dbb19
#   Building wheel for cli-builder (setup.py) ... done
#   Created wheel for cli-builder: filename=cli_builder-0.1.5-py3-none-any.whl size=3332 sha256=a5331297e3adbfedcae4c73d7a6f0b98935d4dc67e7d5c00394d6e50b969aef2
#   Stored in directory: /tmp/pip-ephem-wheel-cache-3ouycfp4/wheels/37/6a/3e/e60dde5f88da7d86b24c1cc79f206fd73f6a621ad1bfe27961
#   Building wheel for getm (setup.py) ... done
#   Created wheel for getm: filename=getm-0.0.4-cp37-cp37m-linux_x86_64.whl size=40148 sha256=761a5f294b6712c4dc87bc027d28931ba16a90cf6b3d771dd6fd97f3e520e98d
#   Stored in directory: /tmp/pip-ephem-wheel-cache-3ouycfp4/wheels/7c/d2/d8/c305db11c0110bc92382d85ab053d2a007b425886065df77c9
#   Building wheel for gs-chunked-io (setup.py) ... done
#   Created wheel for gs-chunked-io: filename=gs_chunked_io-0.5.2-py3-none-any.whl size=9584 sha256=31a360eaf38c8b38d500f1c71ee9c6bfc3dc884aa1a542d38d19ea04279ff91a
#   Stored in directory: /tmp/pip-ephem-wheel-cache-3ouycfp4/wheels/d9/17/31/ce24f67f7553e48d320f575bb0f91006ad96402af8a460b3eb
#   Building wheel for firecloud (setup.py) ... done
#   Created wheel for firecloud: filename=firecloud-0.16.31-py3-none-any.whl size=53438 sha256=38cda46e337b94dc8d44e73b804ac639d72de41ba83c4baeae16abe6593f5e81
#   Stored in directory: /tmp/pip-ephem-wheel-cache-3ouycfp4/wheels/df/5d/2a/cd382b7648f96c90a2fd0114807d83697c9a6c217b0d07d9fe
#   Building wheel for wrapt (setup.py) ... done
#   Created wheel for wrapt: filename=wrapt-1.12.1-cp37-cp37m-linux_x86_64.whl size=71715 sha256=5f56b8da14d11f2d2afb55dd1152380ce6086258788bec0abccd2e2cd517dd00
#   Stored in directory: /tmp/pip-ephem-wheel-cache-3ouycfp4/wheels/62/76/4c/aa25851149f3f6d9785f6c869387ad82b3fd37582fa8147ac6
# Successfully built terra-notebook-utils bgzip cli-builder getm gs-chunked-io firecloud wrapt
# Installing collected packages: six, pyasn1, urllib3, setuptools, rsa, pyparsing, pyasn1-modules, protobuf, idna, charset-normalizer, certifi, cachetools, requests, pytz, packaging, googleapis-common-protos, google-auth, zipp, wrapt, typing-extensions, typed-ast, lazy-object-proxy, google-crc32c, google-api-core, pyrsistent, mccabe, isort, importlib-metadata, google-resumable-media, google-cloud-core, attrs, astroid, pylint, pydot, nose, jsonschema, httplib2, google-cloud-storage, oauth2client, jmespath, gs-chunked-io, getm, firecloud, cli-builder, bgzip, terra-notebook-utils
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow-io 0.18.0 requires tensorflow-io-gcs-filesystem==0.18.0, which is not installed.
# tfx-bsl 1.3.0 requires absl-py<0.13,>=0.9, but you have absl-py 0.13.0 which is incompatible.
# tfx-bsl 1.3.0 requires google-api-python-client<2,>=1.7.11, but you have google-api-python-client 2.19.1 which is incompatible.
# tfx-bsl 1.3.0 requires pyarrow<3,>=1, but you have pyarrow 5.0.0 which is incompatible.
# tensorflow 2.6.0 requires six~=1.15.0, but you have six 1.16.0 which is incompatible.
# tensorflow 2.6.0 requires typing-extensions~=3.7.4, but you have typing-extensions 3.10.0.2 which is incompatible.
# tensorflow-transform 1.3.0 requires absl-py<0.13,>=0.9, but you have absl-py 0.13.0 which is incompatible.
# tensorflow-transform 1.3.0 requires pyarrow<3,>=1, but you have pyarrow 5.0.0 which is incompatible.
# tensorflow-metadata 1.2.0 requires absl-py<0.13,>=0.9, but you have absl-py 0.13.0 which is incompatible.
# tensorflow-io 0.18.0 requires tensorflow<2.6.0,>=2.5.0, but you have tensorflow 2.6.0 which is incompatible.
# jupyterlab-git 0.11.0 requires nbdime<2.0.0,>=1.1.0, but you have nbdime 3.1.0 which is incompatible.
# apache-beam 2.32.0 requires dill<0.3.2,>=0.3.1.1, but you have dill 0.3.4 which is incompatible.
# apache-beam 2.32.0 requires pyarrow<5.0.0,>=0.15.1, but you have pyarrow 5.0.0 which is incompatible.
# apache-beam 2.32.0 requires typing-extensions<3.8.0,>=3.7.0, but you have typing-extensions 3.10.0.2 which is incompatible.
# Successfully installed astroid-2.8.0 attrs-21.2.0 bgzip-0.3.5 cachetools-4.2.4 certifi-2021.5.30 charset-normalizer-2.0.6 cli-builder-0.1.5 firecloud-0.16.31 getm-0.0.4 google-api-core-1.31.3 google-auth-1.35.0 google-cloud-core-1.7.2 google-cloud-storage-1.38.0 google-crc32c-1.3.0 google-resumable-media-1.3.3 googleapis-common-protos-1.53.0 gs-chunked-io-0.5.2 httplib2-0.19.1 idna-3.2 importlib-metadata-4.8.1 isort-5.9.3 jmespath-0.10.0 jsonschema-4.0.1 lazy-object-proxy-1.6.0 mccabe-0.6.1 nose-1.3.7 oauth2client-4.1.3 packaging-21.0 protobuf-3.17.3 pyasn1-0.4.8 pyasn1-modules-0.2.8 pydot-1.4.2 pylint-1.7.2 pyparsing-2.4.7 pyrsistent-0.18.0 pytz-2021.3 requests-2.26.0 rsa-4.7.2 setuptools-58.2.0 six-1.16.0 terra-notebook-utils-0.8.1 typed-ast-1.4.3 typing-extensions-3.10.0.2 urllib3-1.26.7 wrapt-1.12.1 zipp-3.6.0
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# Define some useful functions.

# %%
from terra_notebook_utils import costs, workflows, WORKSPACE_NAME, WORKSPACE_GOOGLE_PROJECT

def list_submissions_chronological(workspace: str=WORKSPACE_NAME,
                                   workspace_namespace: str=WORKSPACE_GOOGLE_PROJECT):
    listing = [(s['submissionDate'], s) for s in workflows.list_submissions(workspace, workspace_namespace)]
    for date, submission in sorted(listing):
        yield submission

def cost_for_submission(submission_id: str,
                        workspace: str=WORKSPACE_NAME,
                        workspace_namespace: str=WORKSPACE_GOOGLE_PROJECT):
    workflows_metadata = workflows.get_all_workflows(submission_id, workspace, workspace_namespace)
    for workflow_id, workflow_metadata in workflows_metadata.items():
        shard_number = 1  # keep track of scattered workflows
        for shard_info in workflows.estimate_workflow_cost(workflow_id, workflow_metadata):
            shard_info['workflow_id'] = workflow_id
            shard_info['shard'] = shard_number
            shard_number += 1
            yield shard_info

def estimate_job_cost(cpus: int, memory_gb: int, disk_gb: int, runtime_hours: float, preemptible: bool) -> float:
    disk = costs.PersistentDisk.estimate(disk_gb, runtime_hours * 3600)
    compute = costs.GCPCustomN1Cost.estimate(cpus, memory_gb, runtime_hours * 3600, preemptible)
    return disk + compute

# %% [markdown]
# List submissions in chronological order.

# %%
for s in list_submissions_chronological():
    print(s['submissionId'], s['submissionDate'], s['status'])
# Out:
# cddabaa0-2b81-4b71-b475-c9ee577538bf 2021-09-15T10:28:24.511Z Done
# 836e43c3-d398-4e3c-b47f-5842352386fc 2021-09-15T14:07:44.815Z Done
# f3466e2b-c5ba-42dd-b78b-67a9817e6e8d 2021-09-15T14:17:06.035Z Done
# b7171dd9-f5f0-4dc9-962a-e7a44771dd5e 2021-09-15T20:42:59.677Z Done
# ba5bf5d6-90a3-4661-aa4a-135aef334a6f 2021-09-16T13:37:32.626Z Done
# 3aa0a027-40bd-4ee9-9d23-194d93bd7f9b 2021-09-16T16:42:07.795Z Done
# 4d5623d2-436a-41c3-8d7c-c52a01540d51 2021-09-21T17:30:21.658Z Aborted
# 35144888-031c-49b3-9102-e9085594d153 2021-09-21T19:09:59.414Z Done
# da5b23a1-73b8-4e2f-ae18-9cadf794e0d2 2021-09-21T22:13:35.123Z Done
# 3021ced2-9617-4c97-a5eb-9ff8ac63d408 2021-09-21T23:02:07.923Z Done
# 0d32d7c9-9512-4db0-b6c9-6654f840de15 2021-09-22T05:29:33.012Z Done
# 1a3f5c55-561b-4dac-bab4-4a237574f3bd 2021-09-22T10:04:54.061Z Done
# 7c6b753c-4b80-4cef-ace4-5438279af7c9 2021-09-22T10:40:10.962Z Done
# ae8fa1bc-bc1a-4753-b013-3db4f11d3ad4 2021-09-22T11:30:15.972Z Aborted
# 925461b3-bc1c-48e0-9e15-7d9a1b9d1443 2021-09-23T09:28:12.174Z Done
# ae120cb2-5a7f-470a-b8e8-ffe624d838c4 2021-09-23T10:57:13.585Z Done
# 12101555-5060-41ca-a3cf-665434207dc0 2021-09-23T11:41:32.960Z Done
# 9798b683-19cf-416c-8e84-392b4eeebc21 2021-09-23T12:27:14.742Z Done
# 98fbe817-2868-41e5-9475-081707024361 2021-09-23T14:38:21.470Z Done
# a50e10b7-d638-476c-8db6-ad4306b780a4 2021-09-25T07:34:25.936Z Done
# 3d05ec9f-1c69-42b8-9b25-e73101c83cef 2021-09-25T12:23:52.190Z Done
# 259584f6-003c-4128-bc47-14f4faf300db 2021-09-25T19:53:00.904Z Done
# 50a3dcd6-f18c-4396-bd41-b6dbd86c0424 2021-09-26T12:15:41.595Z Done
# dc4cf815-0d92-47a2-b684-04950037ab45 2021-10-01T10:32:20.500Z Done
# f03c7688-8a51-48da-b928-020b3d2f8a29 2021-10-01T12:00:54.784Z Done
# 15cf0b45-ea46-4123-8d08-3f6b9590c473 2021-10-01T14:14:56.903Z Done
# d836aca6-9b07-40a3-bbc8-0037de3f7495 2021-10-05T11:06:34.703Z Done
# 5710f9e5-759b-41e9-839f-a8a5af3efb0c 2021-10-05T12:51:05.247Z Done
# 2e5dcc2a-e66e-4446-8f72-71df82ee3b5e 2021-10-05T22:43:13.259Z Done
# f9470c46-4a90-4aa8-89dc-8e35a0065472 2021-10-06T11:01:18.538Z Done
# b4371817-3c4a-4e5d-9e3c-564f6244348e 2021-10-06T11:49:03.547Z Submitted

# %%
submission_id = "5710f9e5-759b-41e9-839f-a8a5af3efb0c"  # Uncomment and insert your submission id here
total_cost = 0
print("%37s" % "workflow_id",
      "%30s" % "task_name",
      "%5s" % "cpus",
      "%7s" % "memory",
      "%7s" % "disk",
      "%9s" % "duration",
      "%7s" % "cost")
for shard_info in cost_for_submission(submission_id):
    total_cost += shard_info['cost']
    print("%37s" % shard_info['workflow_id'],
          "%30s" % shard_info['task_name'],
          "%5i" % shard_info['number_of_cpus'],
          "%5iGB" % shard_info['memory'],
          "%5iGB" % shard_info['disk'],
          "%8.2fh" % (shard_info['duration'] / 3600),  # convert from seconds to hours
          "%7s" % ("$%.2f" % shard_info['cost']))
    shard_info['duration'] /= 3600  # convert from seconds to hours
print("%108s" % ("total_cost: $%.2f" % round(total_cost, 2)))
# Out:
#                           workflow_id                      task_name  cpus  memory    disk  duration    cost
#  d9cf0051-2a80-48b7-985f-1f0dffb36eb3            DiscoverBreakpoints     8     7GB    10GB     3.00h   $0.19
#  d9cf0051-2a80-48b7-985f-1f0dffb36eb3            DiscoverBreakpoints     8     7GB    10GB     2.91h   $0.18
#                                                                                            total_cost: $0.37

# %% [markdown]
# Explore costs for potential workflow configurations and runtimes.

# %%
# Define configurations for: cpus, memory(GB), runtime(hours), preemptible
configurations = [(10, 64, 700, 5, False),
                  (8, 32, 700, 10, False),
                  (10, 64, 700, 5, True),
                  (8, 32, 700, 10, True),
                  (8, 32, 400, 10, True),
                  (8, 32, 400, 10, True),
                  (1, 2, 10, 100, True)]

print("%8s" % "cpus",
      "%8s" % "memory",
      "%8s" % "disk",
      "%8s" % "runtime",
      "%12s" % "preemptible",
      "%8s" % "cost")
for cpus, memory_gb, disk_gb, runtime_hours, preemptible in configurations:
    cost = estimate_job_cost(cpus, memory_gb, disk_gb, runtime_hours, preemptible)
    print("%8i" % cpus,
          "%6iGB" % memory_gb,
          "%6iGB" % disk_gb,
          "%7ih" % runtime_hours,
          "%12s" % str(preemptible),
          "%8s" % ("$%.2f" % cost))
# Out:
#     cpus   memory     disk  runtime  preemptible     cost
#       10     64GB    700GB       5h        False    $3.27
#        8     32GB    700GB      10h        False    $4.46
#       10     64GB    700GB       5h         True    $0.84
#        8     32GB    700GB      10h         True    $1.24
#        8     32GB    400GB      10h         True    $1.08
#        8     32GB    400GB      10h         True    $1.08
#        1      2GB     10GB     100h         True    $0.94

# %% [markdown]
# ## Contributions
# Contributions, bug reports, and feature requests are welcome on:
#   - [terra-notebook-utils GitHub](https://github.com/DataBiosphere/terra-notebook-utils) for general functionality.
#   - [featured-notebooks GitHub](https://github.com/DataBiosphere/featured-notebooks) for this notebook.
